# %% [markdown]
# Table of Contents

# %% [markdown]
# # Movie Analysis

# %% [markdown]
# >Business Problem: Microsoft wants to make a movie company etc etc

# %%
import pandas as pd

# %% [markdown]
# # Load Data

# %%
df= pd.read_csv('data/bom.movie_gross.csv.gz')
df.head()

df.info
#look at missing data

df.isna().sum()
#drop the unknowns

df.dropna(subset=['domestic_gross', 'foreign_gross'])


#use .str to replace then convert to float
df['foreign_gross']= df.foreign_gross.str.replace(',', '').astype(float)

df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
#looking at movies that grossed  more than $100,000,000 domestically

df_highs= df.loc[df['domestic_gross'] > 100000000]
df_highs
# Out:
#                                             title studio  domestic_gross  \
# 0                                     Toy Story 3     BV     415000000.0
# 1                      Alice in Wonderland (2010)     BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                       Inception     WB     292600000.0
# 4                             Shrek Forever After   P/DW     238700000.0
# ...                                           ...    ...             ...
# 3116                            Crazy Rich Asians     WB     174500000.0
# 3119                                     Creed II    MGM     115700000.0
# 3121                              The Equalizer 2   Sony     102100000.0
# 3123                                     The Mule     WB     103800000.0
# 3129                            A Wrinkle in Time     BV     100500000.0
#
#       foreign_gross  year
# 0       652000000.0  2010
# 1       691300000.0  2010
# ...

# %%
#looking at movies that grossed more than $100,000,000 internationally
df_highs_foreign= df.loc[df['foreign_gross'] > 100000000]
df_highs_foreign
# Out:
#                                             title studio  domestic_gross  \
# 0                                     Toy Story 3     BV     415000000.0
# 1                      Alice in Wonderland (2010)     BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                       Inception     WB     292600000.0
# 4                             Shrek Forever After   P/DW     238700000.0
# ...                                           ...    ...             ...
# 3124                      Insidious: The Last Key   Uni.      67700000.0
# 3125                          The Predator (2018)    Fox      51000000.0
# 3126                 Johnny English Strikes Again   Uni.       4400000.0
# 3127                                  Red Sparrow    Fox      46900000.0
# 3134                            The Monkey King 3  WGUSA        187000.0
#
#       foreign_gross  year
# 0       652000000.0  2010
# 1       691300000.0  2010
# ...

# %%
df_highs.groupby(['studio', 'title']).mean().head(50)

df_highs_foreign.groupby(['studio','title']).mean().head(50)
# Out:
#                                                          domestic_gross  \
# studio title
# BV     Alice Through the Looking Glass                       77000000.0
#        Alice in Wonderland (2010)                           334200000.0
#        Ant-Man                                              180200000.0
#        Ant-Man and the Wasp                                 216600000.0
#        Avengers: Age of Ultron                              459000000.0
#        Beauty and the Beast (2017)                          504000000.0
#        Big Hero 6                                           222500000.0
#        Black Panther                                        700100000.0
#        Brave                                                237300000.0
#        Captain America: Civil War                           408100000.0
#        Captain America: The Winter Soldier                  259800000.0
#        Cars 2                                               191500000.0
# ...

# %%
df1=pd.read_csv('data/imdb.title.ratings.csv.gz')
df1.head(50)
# Out:
#         tconst  averagerating  numvotes
# 0   tt10356526            8.3        31
# 1   tt10384606            8.9       559
# 2    tt1042974            6.4        20
# 3    tt1043726            4.2     50352
# 4    tt1060240            6.5        21
# 5    tt1069246            6.2       326
# 6    tt1094666            7.0      1613
# 7    tt1130982            6.4       571
# 8    tt1156528            7.2       265
# 9    tt1161457            4.2       148
# 10   tt1171222            5.1      8296
# 11   tt1174693            5.8      2381
# 12   tt1181840            7.0      5494
# 13   tt1193623            8.0         5
# 14   tt1199588            5.5        74
# 15   tt1204784            5.8         6
# 16   tt1210166            7.6    326657
# 17   tt1212419            6.5     87288
# 18   tt1220911            5.0       941
# 19   tt1229238            7.4    428142
# 20   tt1232829            7.2    477771
# 21   tt1235548            6.6      2725
# ...

# %%
df2=pd.read_csv('data/imdb.title.basics.csv.gz')
df2.head(50)
# Out:
#        tconst                                      primary_title  \
# 0   tt0063540                                          Sunghursh
# 1   tt0066787                    One Day Before the Rainy Season
# 2   tt0069049                         The Other Side of the Wind
# 3   tt0069204                                    Sabse Bada Sukh
# 4   tt0100275                           The Wandering Soap Opera
# 5   tt0111414                                        A Thin Life
# 6   tt0112502                                            Bigfoot
# 7   tt0137204                                    Joe Finds Grace
# 8   tt0139613                                         O Silêncio
# 9   tt0144449                              Nema aviona za Zagreb
# 10  tt0146592                                        Pál Adrienn
# 11  tt0154039                               So Much for Justice!
# 12  tt0159369                 Cooper and Hemingway: The True Gen
# ...

# %%
df_clean=df_imdb_titles.dropna(subset=['genres'])
df_clean.dtype()

# %%
all_genres_str= df.join(df_imdb_titles.genres.unique())

# %%
all_genres_list= all_genres_str.split(',')
all_genres_list

# %%
unique_genres_set=set(all_genres_list)
unique_genres_set

# %%
#genre = 'Action'
for genre in unique_genre_set:
        df_clean.genres.map(lambda val: 1 if genre in val else 0)

# %%
df_clean.genres[0]

# %%
genre = 'Action'
for genre_list in df_clean_genres:
